# %% [markdown]
# <a href="https://colab.research.google.com/github/241b266-Sudhanshu/APS-LAB/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take anothnd write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)er example a
import matplotlib.pyplot as plt
def analyze_numbers(arr):
  even_count=0
  odd_count=0
  greater_than_zero=0

  for num in arr:
    if num%2==0:
      even_count += 1
    else:
      odd_count +=1
    if num > 0:
      greater_than_zero +=1
  return even_count,odd_count,greater_than_zero

n_values = list(range(1, 101))
time_values = []

for n in n_values:

    data = list(range(-n, n + 1))
    analyze_numbers(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity for analyze_numbers")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
from re import search
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.
import matplotlib.pyplot as plt
import math

def binary_search(arr, target):
  left, right = 0, len(arr) - 1
  steps = 0

  while left <= right:
    steps += 1
    mid = (left + right)//2
    if arr[mid] == target:
      return mid, steps
    elif arr[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return -1, steps

data = list(range(1, 1025))
target = 777

index, steps_taken = binary_search(data, target)

print(f"Target {target} found at index {index} in {steps_taken} steps.")
sizes = [2**i for i in range(1, 11)]
steps = [math.ceil(math.log2(n)) for n in sizes]
plt.plot(sizes, steps, marker='o', color='red')
plt.title("Logarithmic Growth of Binary Search Steps")
plt.xlabel("Input Size (n)")
plt.ylabel("Steps (≈ log2(n))")
plt.grid(True)
plt.show()
# Out:
# Target 777 found at index 776 in 10 steps.

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.
import matplotlib.pyplot as plt
import random
import math

def merge_sort(arr):
  if len(arr) <= 1:
    return arr

  mid = len(arr) // 2
  left = merge_sort(arr[:mid])
  right = merge_sort(arr[mid:])
  return merge(left, right)

def merge(left, right):
  result = []
  i = j = 0
  while i < len(left) and j < len(right):
    if left[i] <= right[j]:
      result.append(left[i])
      i += 1
    else:
      result.append(right[j])
      j += 1
  result.extend(left[i:])
  result.extend(right[j:])
  return result


sizes = [2**i for i in range(1, 11)]
complexity = [n * math.log2(n) for n in sizes]

plt.figure(figsize=(10, 6))
plt.plot(sizes, complexity, marker='o', color='purple')
plt.title("Log-Linear Growth (n log n) - Merge Sort")
plt.xlabel("Input Size (n)")
plt.ylabel("Operations (≈ n log n)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
import matplotlib.pyplot as plt

def polynomial_time_example(n):
    count = 0
    for i in range(n):
        for j in range(n):
            count += 1
    return count

n_values = list(range(1, 101))
complexity_values = [polynomial_time_example(n) for n in n_values]

plt.figure(figsize=(10, 6))
plt.plot(n_values, complexity_values, marker='o', color='green')
plt.title("Polynomial Time Complexity O(n^2)")
plt.xlabel("Input Size (n)")
plt.ylabel("Operations (n^2)")
plt.grid(True)
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in exponential time. plot the graph as well, similar to above example
import matplotlib.pyplot as plt
import math

def exponential_time_fibonacci(n):
    if n <= 1:
        return n
    else:
        return exponential_time_fibonacci(n-1) + exponential_time_fibonacci(n-2)


n_values = list(range(1, 21))
complexity_values = [1.618**n for n in n_values]

plt.figure(figsize=(10, 6))
plt.plot(n_values, complexity_values, marker='o', color='red')
plt.title("Exponential Time Complexity O(c^n) - Fibonacci-like Growth")
plt.xlabel("Input Size (n)")
plt.ylabel("Operations (c^n)")
plt.grid(True)
plt.yscale('log')
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#prob_8 plot the similar graph from above
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(1, 10)

f_n = n
g_n = np.log2(n)
h_n = n**2
k_n = 2**n

plt.figure(figsize=(8, 5))
plt.plot(n, f_n, label='f(n)=n', color='blue')
plt.plot(n, g_n, label='g(n)=log2(n)', color='red')
plt.plot(n, h_n, label='h(n)=n^2', color='green')
plt.plot(n, k_n, label='k(n)=2^n', color='gold')

plt.title('Time Complexity Plot')
plt.xlabel('Values of n')
plt.ylabel('Time Complexity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(log n)
import matplotlib.pyplot as plt
import math
import random

def quick_sort(arr):

    if len(arr) <= 1:
        return arr
    else:

        pivot = arr.pop()


        items_greater = []
        items_lower = []

        for item in arr:
            if item > pivot:
                items_greater.append(item)
            else:
                items_lower.append(item)

        return quick_sort(items_lower) + [pivot] + quick_sort(items_greater)


n_values = list(range(1, 101))
time_values = []

for n in n_values:

    random_list = [random.randint(0, 1000) for _ in range(n)]


    quick_sort(random_list)


    if n > 0:
        time_values.append(n * math.log(n))
    else:
        time_values.append(0)


plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (Theoretical Steps)")
plt.title("Log-Linear Time Complexity O(n log n) for Quick Sort")
plt.show()
